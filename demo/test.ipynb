# %%
# !pip install py-cpuinfo

import cpuinfo
cpuinfo.get_cpu_info()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\BartD\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# {'python_version': '3.12.4.final.0 (64 bit)',
#  'cpuinfo_version': [9, 0, 0],
#  'cpuinfo_version_string': '9.0.0',
#  'arch': 'X86_64',
#  'bits': 64,
#  'count': 16,
#  'arch_string_raw': 'AMD64',
#  'vendor_id_raw': 'AuthenticAMD',
#  'brand_raw': 'AMD Ryzen 7 PRO 6850H with Radeon Graphics',
#  'hz_actual_friendly': '3.2010 GHz',
#  'hz_actual': [3201000000, 0],
#  'l2_cache_size': 4194304,
#  'stepping': 1,
#  'model': 68,
#  'family': 25,
#  'l3_cache_size': 16777216,
#  'hz_advertised_friendly': '3.1940 GHz',
#  'hz_advertised': [3194000000, 0],
#  'flags': ['3dnow',
#   '3dnowext',
#   '3dnowprefetch',
#   'abm',
#   'adx',
#   'aes',
#   'apic',
#   'avx',
#   'avx2',
# ...
